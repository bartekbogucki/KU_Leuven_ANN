# %% [markdown]
# #Artificial Neural Networks and Deep Learning
# ##Assignment 3.1 - Autoencoders and Stacked Autoencoders
#
# Prof. Dr. Ir. Johan A. K. Suykens
#
# In this file, we will implement two network architectures from scratch: (1) Autoencoders; (2) Stacked Autoencoders.
#
# We will train both networks on the MNIST dataset under reconstruction learning task. All training will be conducted on a single T4 GPU.

# %%
# Please first load your google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Please go to Edit > Notebook settings > Hardware accelerator > choose "T4 GPU"
# Now check if you have loaded the GPU successfully
# !nvidia-smi
# Out:
# Thu May  8 13:41:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   76C    P0             34W /   70W |     188MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Autoencoder
# In this section, we implement an Autoencoder from scratch and trainit on the MNIST dataset. With this autoencoder, we pass input data through an encoder making a compressed representation of the input, and then pass this representation to the following decoder to reconstruct the input data.
# Note that in this exercise session we will be using  ``PyTorch`` instead of ``Keras`` for building and training our neural networks.

# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms

# Set the seed for reproducibility. Don't forget to comment out this line when averaging over different runs
torch.manual_seed(42)

# Convert data to torch.FloatTensor
transform = transforms.ToTensor()


train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

# Select only a part of the dataset to speed up training times
num_train_samples = 10000
num_test_samples = 1000

# Randomly select a subset of samples
train_indices = torch.randperm(len(train_data))[:num_train_samples]
test_indices = torch.randperm(len(test_data))[:num_test_samples]

# Create subset samplers to be used in the dataloader
train_subset_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
test_subset_sampler = torch.utils.data.SubsetRandomSampler(test_indices)

# %% [markdown]
# ## Create training and test dataloaders
#
#
# Dataloaders are used for efficiently loading, batching, and managing datasets in PyTorch.
# During training dataloaders feed the data into the network batch by batch instead of the whole dataset at once. This allows us to handle larger datasets without running out of memory.

# %%
# Choose how many samples per batch to load
# You can tune the batch size
batch_size = 32

# Prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=batch_size,
                                           sampler = train_subset_sampler,
                                           num_workers=0)
test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=batch_size,
                                          sampler = test_subset_sampler,
                                          num_workers=0)

# %% [markdown]
# ## Visualize the data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Obtain one batch of training images
images, labels = next(iter(train_loader)) # iter() creates an iterator over the batches in the dataloader and next() selects the next batch from this iterator.
images = images.numpy() #.numpy() turns the torch.tensor into a numpy array

# Get one image from the batch
img = np.squeeze(images[0])

fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')

# %% [markdown]
# ## Build the Linear Autoencoder
# We now train a linear autoencoder on MINIST dataset.
# Images of original size 28$\times$28 will be flattened into 784-dimensional vectors.
# Note that images from this dataset are already normalized so that the values are between 0 and 1.
# Since the images are normalized between 0 and 1, we need to use a sigmoid activation on the output layer to get values that match this input value range.
#
# The encoder and decoder in the Autoencoder are built with one linear layer where you can tune the dimension of the hidden representation, i.e., ``encoding_dim``, to obtain models with different size.

# %%
import torch.nn as nn
import torch.nn.functional as F

# Define the NN architecture
class Autoencoder(nn.Module):
    def __init__(self, encoding_dim):
        super(Autoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Linear(784, encoding_dim)
        # Decoder
        self.decoder = nn.Linear(encoding_dim, 784)

    def forward(self, x):
        # Define feedforward behavior
        # and scale the *output* layer with a sigmoid activation function

        # Pass x into encoder
        out = F.relu(self.encoder(x))
        # Pass out into decoder
        out = torch.sigmoid(self.decoder(out))

        return out

# %%
# Initialize the NN
# You can change the encoding_dim to obtain models with different size
encoding_dim = 32
model = Autoencoder(encoding_dim)

# Send model to GPU if available
if torch.cuda.is_available():
  model.cuda()
print(model)
# Out:
# Autoencoder(
#   (encoder): Linear(in_features=784, out_features=32, bias=True)
#   (decoder): Linear(in_features=32, out_features=784, bias=True)
# )

# %% [markdown]
# ## Training on MNIST
# Training a neural network in PyTorch involves manually defining the training loop.
# Here data processing, forward pass, loss computation, and optimization are explicitly specified.
#
# Since we work on reconstruction learning tasks, we do not need the labels here but only the images.
# The loss function should choose the MSE loss for reconstruction.

# %%
# Specify the loss function
criterion = nn.MSELoss()

# We use Adam as the optimizer with a fixed learning rate of 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Choose the number of Epochs to train the network
n_epochs = 20
# Set model to training mode
model.train()

for epoch in range(n_epochs):
    # Monitor training loss
    train_loss = 0.0

    # Train the model #
    # Feed the data into the network batch by batch using the dataloader
    for batch_data in train_loader:
        # _ stands in for labels
        # we do not need labels when conducting reconstruction
        images, _ = batch_data
        # Flatten images and send images to GPU
        images = images.view(images.size(0), -1)
        # Send images to GPU if possible
        if torch.cuda.is_available():
          images = images.cuda()
        # Clear the gradients of all optimized variables
        optimizer.zero_grad()
        # Forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(images)
        # Calculate the loss between output and input images
        loss = criterion(outputs, images)
        # Backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # Perform a single optimization step (parameter update)
        optimizer.step()
        # Update running training loss
        train_loss += loss.item()*images.size(0)

    # Print avg training statistics
    train_loss = train_loss/len(train_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(
        epoch,
        train_loss
        ))
# Out:
# Epoch: 0 	Training Loss: 2.386593
# Epoch: 1 	Training Loss: 1.315528
# Epoch: 2 	Training Loss: 1.040679
# Epoch: 3 	Training Loss: 0.878057
# Epoch: 4 	Training Loss: 0.759522
# Epoch: 5 	Training Loss: 0.688439
# Epoch: 6 	Training Loss: 0.636693
# Epoch: 7 	Training Loss: 0.597742
# Epoch: 8 	Training Loss: 0.568476
# Epoch: 9 	Training Loss: 0.546332
# Epoch: 10 	Training Loss: 0.530176
# Epoch: 11 	Training Loss: 0.518377
# Epoch: 12 	Training Loss: 0.509132
# Epoch: 13 	Training Loss: 0.501971
# Epoch: 14 	Training Loss: 0.495893
# Epoch: 15 	Training Loss: 0.491787
# Epoch: 16 	Training Loss: 0.488524
# Epoch: 17 	Training Loss: 0.485783
# Epoch: 18 	Training Loss: 0.483460
# Epoch: 19 	Training Loss: 0.480828

# %% [markdown]
# ## Evaluation on test set
# We now evaluate the reconstruction results on the unseen test set.
# We plot the original test images and their corresponding reconstruction ones.

# %%
# Set model to evaluation mode
model.eval()

# Monitor test loss
test_loss = 0.0

# Disable gradient computation
with torch.no_grad():
    # Iterate over the test data
    for batch_data in test_loader:
        # Extract images from the batch
        images, _ = batch_data
        # Flatten images and send them to GPU
        images = images.view(images.size(0), -1)
        # Send to GPU
        if torch.cuda.is_available():
          images = images.cuda()
        # Forward pass: compute predicted outputs by passing inputs to the model
        outputs = model(images)
        # Calculate the loss between output and input images
        loss = criterion(outputs, images)
        # Update test loss
        test_loss += loss.item()*images.size(0)

# Compute average test loss
test_loss = test_loss/len(test_loader)

# Print test loss
print('Test Loss: {:.6f}'.format(test_loss))
# Out:
# Test Loss: 0.459490

# %%
# Obtain one batch of test images
test_images, test_labels = next(iter(test_loader))

test_images_flatten = test_images.view(test_images.size(0), -1)
# Set model to evaluation mode
model.eval()
# Send model back to CPU
model.cpu()
# Get sample outputs
output = model(test_images_flatten)
# Prep images for display
test_images = test_images.numpy()

# Output is resized into a batch of images
output = output.view(batch_size, 1, 28, 28)
# Use detach when it's an output that requires_grad
output = output.detach().numpy()

# Plot the first ten input images and then reconstructed images
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(25,4))

# Input images on top row, reconstructions on bottom
for test_images, row in zip([test_images, output], axes):
    for img, ax in zip(test_images, row):
        ax.imshow(np.squeeze(img), cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Stacked Autoencoder
# In this section, we implement the Stacked Autoencoder from scratch and train it on the MNIST dataset.
# The training process is with two steps: (1) each layer is trained separately; (2) the network is trained as a whole.
#
# We first load the dataset as follows:

# %%
import torch
from torch import nn, optim, functional, utils

from torch.nn import BCELoss, init
from torch.utils.data.dataloader import DataLoader
import torchvision
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.datasets import MNIST

import time, os

# We automate the dataloading process for future use
def get_mnist_loader(batch_size=32, num_train_samples = 6000, num_test_samples = 1000):
    """

    :return: train_loader, test_loader
    """

    transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to PyTorch tensor
    transforms.Normalize((0.0,), (1.0,))  # Normalize the tensor with mean 0 and standard deviation 1
    ])
    train_dataset = MNIST(root='../data',
                          train=True,
                          transform=transform,
                          download=True)
    test_dataset = MNIST(root='../data',
                         train=False,
                         transform=transform,
                         download=True)

    # Fix the random seed to select the same subset of samples
    torch.manual_seed(42)
    # Randomly select a subset of samples
    train_indices = torch.randperm(len(train_dataset))[:num_train_samples]
    test_indices = torch.randperm(len(test_dataset))[:num_test_samples]

    # Create subset samplers to be used in the dataloader
    train_subset_sampler = torch.utils.data.SubsetRandomSampler(train_indices)
    test_subset_sampler = torch.utils.data.SubsetRandomSampler(test_indices)

    train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                               batch_size=batch_size,
                                               sampler = train_subset_sampler)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                              batch_size=batch_size,
                                              sampler = test_subset_sampler)
    return train_loader, test_loader

# %% [markdown]
# ## Build the Stacked Autoencoder
# Before building the Stacked Autoencoder, we need to build the Autoencoder layer first.

# %%
class AutoEncoderLayer(nn.Module):
    """
    fully-connected linear layers for stacked autoencoders.
    This module can automatically be trained when training each layer is enabled
    Yes, this is much like the simplest auto-encoder
    """
    def __init__(self, input_dim=None, hidden_dim=None, SelfTraining=False):
        super(AutoEncoderLayer, self).__init__()
        # If input_dim is None or hidden_dim is None:
        # raise ValueError
        self.in_features = input_dim
        self.out_features = hidden_dim
        # Whether to conduct layer-by-layer pre-training, or train the entire network
        self.is_training_self = SelfTraining
        self.encoder = nn.Sequential(
            nn.Linear(self.in_features, self.out_features, bias=True),
            nn.Sigmoid()  # use Sigmoid activation function
        )
        self.decoder = nn.Sequential(
            nn.Linear(self.out_features, self.in_features, bias=True),
            nn.Sigmoid()
        )
        #self._initialize_weights()

    def forward(self, x):
        out = self.encoder(x)
        if self.is_training_self:
            return self.decoder(out) # If the layer is not in training mode, it will just encode the data and pass it through
        else:
            return out

    def lock_grad(self):
        for param in self.parameters():
            param.requires_grad = False

    def acquire_grad(self):
        for param in self.parameters():
            param.requires_grad = True

    @property
    def input_dim(self):
        return self.in_features

    @property
    def output_dim(self):
        return self.out_features

    @property
    def is_training_layer(self):
        return self.is_training_self

    @is_training_layer.setter
    def is_training_layer(self, other: bool):
        self.is_training_self = other

# %% [markdown]
# ## Build the stacked autoencoder
#
# Here we stack the autoencoder layers together and add a classification layer at the end

# %%
class StackedAutoEncoderClassifier(nn.Module):
    """
    Stack the trained autoencoder layers and add a classification layer at the end
    """

    def __init__(self, autoencoder_list=None, num_classes=10):
        super(StackedAutoEncoderClassifier, self).__init__()
        # Use only the encoder parts of the autoencoders
        self.encoder_layers = nn.ModuleList([autoencoder.encoder for autoencoder in autoencoder_list])
        self.num_classes = num_classes

        # Classification layer
        self.classification_layer = nn.Linear(autoencoder_list[-1].out_features, num_classes)
        #Note that we don't implement a softmax activation, as this is already taken care of in the CrossEntropyLoss class
        #(see https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html)

    def forward(self, x):
        encoded_representation = x
        for layer in self.encoder_layers:
            encoded_representation = layer(encoded_representation)

        # Classification layer
        output = self.classification_layer(encoded_representation)
        return output

# %% [markdown]
# ## The training function of each layer
# We need to freeze the parameters in the previous layers when training the current layer.

# %%
def train_layer(layers_list=None, train_loader= None, test_loader= None, layer=None, epochs=None, validate=True):
    """
    Greedy layer-wise training: when training the i-th layer, freeze the i-1 layer
    :param layers_list: all autoencoder layers to train
    :param layer: which autoencoder layer to train
    :return:
    """
    if torch.cuda.is_available():
        for model in layers_list:
            model.cuda()

    optimizer = optim.SGD(layers_list[layer].parameters(), lr=0.1)
    criterion = torch.nn.MSELoss()

    # Train
    for epoch_index in range(epochs):
        sum_loss = 0.

        # Freeze the parameters of all layers before the current layer
        # Layer 0 has no previous layer
        if layer != 0:
            for index in range(layer):
                # In addition to freezing parameters
                # the output return method of the frozen layer must also be set.
                layers_list[index].lock_grad()
                layers_list[index].is_training_layer = False

        for batch_index, (train_data, _) in enumerate(train_loader):
            # Generate input data
            if torch.cuda.is_available():
                train_data = train_data.cuda()  # Put data onto GPU
            out = train_data.view(train_data.size(0), -1)

            # Perform forward calculation on the frozen layers before (layer-1)-th layer
            if layer != 0:
                for l in range(layer):
                    out = layers_list[l](out)

            # Train the layer-th layer
            pred = layers_list[layer](out)

            optimizer.zero_grad()
            loss = criterion(pred, out)
            sum_loss += loss
            loss.backward()
            optimizer.step()
            #if (batch_index + 1) % 20 == 0:
        print("Train Layer: {}, Epoch: {}/{}, Iter: {}/{}, Loss: {:.4f}".format(
            layer, (epoch_index + 1), epochs, (batch_index + 1), len(train_loader), loss))

        if validate:
            pass

# %% [markdown]
# ## The training function of the whole network
# Now we unfreeze all the parameters in the network that are previously frozen for the layer training.

# %%
def train_classifier(model=None, train_loader=None, test_loader=None, epochs=20, fine_tuning = False):

    print(">> start training whole model")
    if torch.cuda.is_available():
        model.cuda()

    # unfreeze the parameters frozen in pre-training if needed
    if fine_tuning:
      for param in model.parameters():
          param.requires_grad = True
      training_phase = 'Fine-Tuning'
    else:
      training_phase = 'Classifier'

    optimizer = optim.SGD(model.parameters(), lr=1)
    criterion = nn.CrossEntropyLoss()

    # Set the model to training mode
    model.train()

    # train
    for epoch_index in range(epochs):
        sum_loss = 0.
        for batch_index, (train_data, train_labels) in enumerate(train_loader):
            if torch.cuda.is_available():
                train_data, train_labels = train_data.cuda(), train_labels.cuda()
            x = train_data.view(train_data.size(0), -1)

            predicted_labels = model(x)

            optimizer.zero_grad()
            loss = criterion(predicted_labels, train_labels)
            sum_loss += loss
            loss.backward()
            optimizer.step()

        print("Train {}, Epoch: {}/{}, Iter: {}/{}, Loss: {:.4f}".format(training_phase, (epoch_index + 1), epochs, (batch_index + 1), len(train_loader), loss))

    print("<< end training whole model")
    print("Calculating accuracy on the whole test set")

    # Set model to evaluation mode
    model.eval()

    # Calculate accuracy on the test set
    total_correct = 0
    total_samples = 0
    with torch.no_grad():
        for batch_data in test_loader:
            images, labels = batch_data
            images = images.view(images.size(0), -1)
            if torch.cuda.is_available():
              images, labels = images.cuda(), labels.cuda()
            outputs = model(images)
            # Get the highest value for each point to get the label
            _, predicted_labels = torch.max(outputs.data, 1)
            # Count number of correct predictions in the batch
            total_correct += (predicted_labels == labels).sum().item()
            total_samples += labels.size(0)


    # Compute average test loss
    accuracy = total_correct / total_samples
    print('Accuracy on the test set: {:.6f}'.format(accuracy))
    return model, accuracy

# %% [markdown]
# ## Let's start training!
# The default network is trained with layer epochs 10, classifier epochs 10, fine-tuning epochs 20, batch size of 128. You can try to change the hyper-parameters to obtain better reconstruction performance.

# %%
# You can change the hyper-parameters here
# Be sure to try out different combinations of epochs for the pretraining and fine-tuning
num_layer_wise_epochs = 20
num_classifier_epochs = 10
num_finetuning_epochs = 30
batch_size = 128

# %%
# Get the dataloaders of the training dataset
train_loader, test_loader = get_mnist_loader(batch_size=batch_size)

input_dim = 784
# Define the autoencoder layers
# Try different values for the dimensions of the hidden layers and the number of layers
encoder_1 = AutoEncoderLayer(input_dim = input_dim, hidden_dim = 256, SelfTraining=True)
encoder_2 = AutoEncoderLayer(input_dim = 256, hidden_dim = 64, SelfTraining=True)

encoders_list = [encoder_1, encoder_2]
num_layers = len(encoders_list)


# Pre-train each layer
for level in range(num_layers):
   train_layer(layers_list=encoders_list, train_loader=train_loader, test_loader=test_loader, layer=level, epochs=num_layer_wise_epochs, validate=True)

# Build the stacked autoencoder
SAE_model = StackedAutoEncoderClassifier(autoencoder_list=encoders_list, num_classes = 10)
# Print the model
print(SAE_model)

# First train the classification layer
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_classifier_epochs, fine_tuning = False)

# Train the whole model and perform fine-tuning
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_finetuning_epochs, fine_tuning = True)


# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
import os
if not os.path.exists('./models'):
   os.makedirs('./models')
torch.save(SAE_model, './models/sae_model.pt')
# Out:
# Train Layer: 0, Epoch: 1/20, Iter: 47/47, Loss: 0.2178
# Train Layer: 0, Epoch: 2/20, Iter: 47/47, Loss: 0.2037
# Train Layer: 0, Epoch: 3/20, Iter: 47/47, Loss: 0.1910
# Train Layer: 0, Epoch: 4/20, Iter: 47/47, Loss: 0.1802
# Train Layer: 0, Epoch: 5/20, Iter: 47/47, Loss: 0.1697
# Train Layer: 0, Epoch: 6/20, Iter: 47/47, Loss: 0.1603
# Train Layer: 0, Epoch: 7/20, Iter: 47/47, Loss: 0.1516
# Train Layer: 0, Epoch: 8/20, Iter: 47/47, Loss: 0.1448
# Train Layer: 0, Epoch: 9/20, Iter: 47/47, Loss: 0.1382
# Train Layer: 0, Epoch: 10/20, Iter: 47/47, Loss: 0.1304
# Train Layer: 0, Epoch: 11/20, Iter: 47/47, Loss: 0.1253
# Train Layer: 0, Epoch: 12/20, Iter: 47/47, Loss: 0.1202
# Train Layer: 0, Epoch: 13/20, Iter: 47/47, Loss: 0.1158
# Train Layer: 0, Epoch: 14/20, Iter: 47/47, Loss: 0.1102
# Train Layer: 0, Epoch: 15/20, Iter: 47/47, Loss: 0.1062
# Train Layer: 0, Epoch: 16/20, Iter: 47/47, Loss: 0.1040
# Train Layer: 0, Epoch: 17/20, Iter: 47/47, Loss: 0.1020
# Train Layer: 0, Epoch: 18/20, Iter: 47/47, Loss: 0.0985
# Train Layer: 0, Epoch: 19/20, Iter: 47/47, Loss: 0.0948
# Train Layer: 0, Epoch: 20/20, Iter: 47/47, Loss: 0.0947
# Train Layer: 1, Epoch: 1/20, Iter: 47/47, Loss: 0.0115
# Train Layer: 1, Epoch: 2/20, Iter: 47/47, Loss: 0.0107
# Train Layer: 1, Epoch: 3/20, Iter: 47/47, Loss: 0.0106
# Train Layer: 1, Epoch: 4/20, Iter: 47/47, Loss: 0.0098
# Train Layer: 1, Epoch: 5/20, Iter: 47/47, Loss: 0.0091
# Train Layer: 1, Epoch: 6/20, Iter: 47/47, Loss: 0.0081
# Train Layer: 1, Epoch: 7/20, Iter: 47/47, Loss: 0.0077
# Train Layer: 1, Epoch: 8/20, Iter: 47/47, Loss: 0.0077
# Train Layer: 1, Epoch: 9/20, Iter: 47/47, Loss: 0.0064
# Train Layer: 1, Epoch: 10/20, Iter: 47/47, Loss: 0.0066
# Train Layer: 1, Epoch: 11/20, Iter: 47/47, Loss: 0.0066
# Train Layer: 1, Epoch: 12/20, Iter: 47/47, Loss: 0.0063
# Train Layer: 1, Epoch: 13/20, Iter: 47/47, Loss: 0.0058
# Train Layer: 1, Epoch: 14/20, Iter: 47/47, Loss: 0.0054
# Train Layer: 1, Epoch: 15/20, Iter: 47/47, Loss: 0.0054
# Train Layer: 1, Epoch: 16/20, Iter: 47/47, Loss: 0.0051
# Train Layer: 1, Epoch: 17/20, Iter: 47/47, Loss: 0.0046
# Train Layer: 1, Epoch: 18/20, Iter: 47/47, Loss: 0.0045
# Train Layer: 1, Epoch: 19/20, Iter: 47/47, Loss: 0.0041
# Train Layer: 1, Epoch: 20/20, Iter: 47/47, Loss: 0.0045
# StackedAutoEncoderClassifier(
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Sigmoid()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (classification_layer): Linear(in_features=64, out_features=10, bias=True)
# )
# >> start training whole model
# Train Classifier, Epoch: 1/10, Iter: 47/47, Loss: 2.2966
# Train Classifier, Epoch: 2/10, Iter: 47/47, Loss: 2.2881
# Train Classifier, Epoch: 3/10, Iter: 47/47, Loss: 2.2879
# Train Classifier, Epoch: 4/10, Iter: 47/47, Loss: 2.2777
# Train Classifier, Epoch: 5/10, Iter: 47/47, Loss: 2.3010
# Train Classifier, Epoch: 6/10, Iter: 47/47, Loss: 2.2148
# Train Classifier, Epoch: 7/10, Iter: 47/47, Loss: 2.2496
# Train Classifier, Epoch: 8/10, Iter: 47/47, Loss: 2.1662
# Train Classifier, Epoch: 9/10, Iter: 47/47, Loss: 2.4331
# Train Classifier, Epoch: 10/10, Iter: 47/47, Loss: 2.3224
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.277000
# >> start training whole model
# Train Fine-Tuning, Epoch: 1/30, Iter: 47/47, Loss: 1.1267
# Train Fine-Tuning, Epoch: 2/30, Iter: 47/47, Loss: 0.8280
# Train Fine-Tuning, Epoch: 3/30, Iter: 47/47, Loss: 0.6377
# Train Fine-Tuning, Epoch: 4/30, Iter: 47/47, Loss: 0.5516
# Train Fine-Tuning, Epoch: 5/30, Iter: 47/47, Loss: 0.7577
# Train Fine-Tuning, Epoch: 6/30, Iter: 47/47, Loss: 0.3916
# Train Fine-Tuning, Epoch: 7/30, Iter: 47/47, Loss: 0.3308
# Train Fine-Tuning, Epoch: 8/30, Iter: 47/47, Loss: 0.3450
# Train Fine-Tuning, Epoch: 9/30, Iter: 47/47, Loss: 0.3033
# Train Fine-Tuning, Epoch: 10/30, Iter: 47/47, Loss: 0.2112
# Train Fine-Tuning, Epoch: 11/30, Iter: 47/47, Loss: 0.2995
# Train Fine-Tuning, Epoch: 12/30, Iter: 47/47, Loss: 0.3579
# Train Fine-Tuning, Epoch: 13/30, Iter: 47/47, Loss: 0.2150
# Train Fine-Tuning, Epoch: 14/30, Iter: 47/47, Loss: 0.3022
# Train Fine-Tuning, Epoch: 15/30, Iter: 47/47, Loss: 0.1755
# Train Fine-Tuning, Epoch: 16/30, Iter: 47/47, Loss: 0.2328
# Train Fine-Tuning, Epoch: 17/30, Iter: 47/47, Loss: 0.2626
# Train Fine-Tuning, Epoch: 18/30, Iter: 47/47, Loss: 0.2905
# Train Fine-Tuning, Epoch: 19/30, Iter: 47/47, Loss: 0.1821
# Train Fine-Tuning, Epoch: 20/30, Iter: 47/47, Loss: 0.1542
# Train Fine-Tuning, Epoch: 21/30, Iter: 47/47, Loss: 0.2553
# Train Fine-Tuning, Epoch: 22/30, Iter: 47/47, Loss: 0.2108
# Train Fine-Tuning, Epoch: 23/30, Iter: 47/47, Loss: 0.1449
# Train Fine-Tuning, Epoch: 24/30, Iter: 47/47, Loss: 0.1045
# Train Fine-Tuning, Epoch: 25/30, Iter: 47/47, Loss: 0.2047
# Train Fine-Tuning, Epoch: 26/30, Iter: 47/47, Loss: 0.0958
# Train Fine-Tuning, Epoch: 27/30, Iter: 47/47, Loss: 0.1740
# Train Fine-Tuning, Epoch: 28/30, Iter: 47/47, Loss: 0.0925
# Train Fine-Tuning, Epoch: 29/30, Iter: 47/47, Loss: 0.0815
# Train Fine-Tuning, Epoch: 30/30, Iter: 47/47, Loss: 0.1235
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.928000

# %%
# Get the dataloaders of the training dataset
train_loader, test_loader = get_mnist_loader(batch_size=batch_size)

input_dim = 784
# Define the autoencoder layers
# Try different values for the dimensions of the hidden layers and the number of layers
encoder_1 = AutoEncoderLayer(input_dim = input_dim, hidden_dim = 512, SelfTraining=True)
encoder_2 = AutoEncoderLayer(input_dim = 512, hidden_dim = 128, SelfTraining=True)

encoders_list = [encoder_1, encoder_2]
num_layers = len(encoders_list)


# Pre-train each layer
for level in range(num_layers):
   train_layer(layers_list=encoders_list, train_loader=train_loader, test_loader=test_loader, layer=level, epochs=num_layer_wise_epochs, validate=True)

# Build the stacked autoencoder
SAE_model = StackedAutoEncoderClassifier(autoencoder_list=encoders_list, num_classes = 10)
# Print the model
print(SAE_model)

# First train the classification layer
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_classifier_epochs, fine_tuning = False)

# Train the whole model and perform fine-tuning
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_finetuning_epochs, fine_tuning = True)


# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
import os
if not os.path.exists('./models'):
   os.makedirs('./models')
torch.save(SAE_model, './models/sae_model2.pt')
# Out:
# Train Layer: 0, Epoch: 1/20, Iter: 47/47, Loss: 0.2074
# Train Layer: 0, Epoch: 2/20, Iter: 47/47, Loss: 0.1841
# Train Layer: 0, Epoch: 3/20, Iter: 47/47, Loss: 0.1642
# Train Layer: 0, Epoch: 4/20, Iter: 47/47, Loss: 0.1494
# Train Layer: 0, Epoch: 5/20, Iter: 47/47, Loss: 0.1367
# Train Layer: 0, Epoch: 6/20, Iter: 47/47, Loss: 0.1252
# Train Layer: 0, Epoch: 7/20, Iter: 47/47, Loss: 0.1180
# Train Layer: 0, Epoch: 8/20, Iter: 47/47, Loss: 0.1108
# Train Layer: 0, Epoch: 9/20, Iter: 47/47, Loss: 0.1069
# Train Layer: 0, Epoch: 10/20, Iter: 47/47, Loss: 0.1008
# Train Layer: 0, Epoch: 11/20, Iter: 47/47, Loss: 0.0992
# Train Layer: 0, Epoch: 12/20, Iter: 47/47, Loss: 0.0942
# Train Layer: 0, Epoch: 13/20, Iter: 47/47, Loss: 0.0910
# Train Layer: 0, Epoch: 14/20, Iter: 47/47, Loss: 0.0884
# Train Layer: 0, Epoch: 15/20, Iter: 47/47, Loss: 0.0862
# Train Layer: 0, Epoch: 16/20, Iter: 47/47, Loss: 0.0850
# Train Layer: 0, Epoch: 17/20, Iter: 47/47, Loss: 0.0845
# Train Layer: 0, Epoch: 18/20, Iter: 47/47, Loss: 0.0811
# Train Layer: 0, Epoch: 19/20, Iter: 47/47, Loss: 0.0820
# Train Layer: 0, Epoch: 20/20, Iter: 47/47, Loss: 0.0820
# Train Layer: 1, Epoch: 1/20, Iter: 47/47, Loss: 0.0088
# Train Layer: 1, Epoch: 2/20, Iter: 47/47, Loss: 0.0082
# Train Layer: 1, Epoch: 3/20, Iter: 47/47, Loss: 0.0078
# Train Layer: 1, Epoch: 4/20, Iter: 47/47, Loss: 0.0071
# Train Layer: 1, Epoch: 5/20, Iter: 47/47, Loss: 0.0066
# Train Layer: 1, Epoch: 6/20, Iter: 47/47, Loss: 0.0062
# Train Layer: 1, Epoch: 7/20, Iter: 47/47, Loss: 0.0059
# Train Layer: 1, Epoch: 8/20, Iter: 47/47, Loss: 0.0056
# Train Layer: 1, Epoch: 9/20, Iter: 47/47, Loss: 0.0052
# Train Layer: 1, Epoch: 10/20, Iter: 47/47, Loss: 0.0050
# Train Layer: 1, Epoch: 11/20, Iter: 47/47, Loss: 0.0047
# Train Layer: 1, Epoch: 12/20, Iter: 47/47, Loss: 0.0043
# Train Layer: 1, Epoch: 13/20, Iter: 47/47, Loss: 0.0043
# Train Layer: 1, Epoch: 14/20, Iter: 47/47, Loss: 0.0041
# Train Layer: 1, Epoch: 15/20, Iter: 47/47, Loss: 0.0040
# Train Layer: 1, Epoch: 16/20, Iter: 47/47, Loss: 0.0037
# Train Layer: 1, Epoch: 17/20, Iter: 47/47, Loss: 0.0036
# Train Layer: 1, Epoch: 18/20, Iter: 47/47, Loss: 0.0034
# Train Layer: 1, Epoch: 19/20, Iter: 47/47, Loss: 0.0032
# Train Layer: 1, Epoch: 20/20, Iter: 47/47, Loss: 0.0033
# StackedAutoEncoderClassifier(
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=512, bias=True)
#       (1): Sigmoid()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=512, out_features=128, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (classification_layer): Linear(in_features=128, out_features=10, bias=True)
# )
# >> start training whole model
# Train Classifier, Epoch: 1/10, Iter: 47/47, Loss: 2.3052
# Train Classifier, Epoch: 2/10, Iter: 47/47, Loss: 2.2979
# Train Classifier, Epoch: 3/10, Iter: 47/47, Loss: 2.2859
# Train Classifier, Epoch: 4/10, Iter: 47/47, Loss: 2.2794
# Train Classifier, Epoch: 5/10, Iter: 47/47, Loss: 2.2356
# Train Classifier, Epoch: 6/10, Iter: 47/47, Loss: 2.1990
# Train Classifier, Epoch: 7/10, Iter: 47/47, Loss: 2.2142
# Train Classifier, Epoch: 8/10, Iter: 47/47, Loss: 2.2085
# Train Classifier, Epoch: 9/10, Iter: 47/47, Loss: 2.1180
# Train Classifier, Epoch: 10/10, Iter: 47/47, Loss: 2.2046
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.308000
# >> start training whole model
# Train Fine-Tuning, Epoch: 1/30, Iter: 47/47, Loss: 1.2152
# Train Fine-Tuning, Epoch: 2/30, Iter: 47/47, Loss: 0.8022
# Train Fine-Tuning, Epoch: 3/30, Iter: 47/47, Loss: 0.7549
# Train Fine-Tuning, Epoch: 4/30, Iter: 47/47, Loss: 0.6515
# Train Fine-Tuning, Epoch: 5/30, Iter: 47/47, Loss: 0.3923
# Train Fine-Tuning, Epoch: 6/30, Iter: 47/47, Loss: 0.3725
# Train Fine-Tuning, Epoch: 7/30, Iter: 47/47, Loss: 0.5806
# Train Fine-Tuning, Epoch: 8/30, Iter: 47/47, Loss: 0.3259
# Train Fine-Tuning, Epoch: 9/30, Iter: 47/47, Loss: 0.3886
# Train Fine-Tuning, Epoch: 10/30, Iter: 47/47, Loss: 0.3646
# Train Fine-Tuning, Epoch: 11/30, Iter: 47/47, Loss: 0.3359
# Train Fine-Tuning, Epoch: 12/30, Iter: 47/47, Loss: 0.2997
# Train Fine-Tuning, Epoch: 13/30, Iter: 47/47, Loss: 0.2423
# Train Fine-Tuning, Epoch: 14/30, Iter: 47/47, Loss: 0.3375
# Train Fine-Tuning, Epoch: 15/30, Iter: 47/47, Loss: 0.1785
# Train Fine-Tuning, Epoch: 16/30, Iter: 47/47, Loss: 0.1938
# Train Fine-Tuning, Epoch: 17/30, Iter: 47/47, Loss: 0.2521
# Train Fine-Tuning, Epoch: 18/30, Iter: 47/47, Loss: 0.2512
# Train Fine-Tuning, Epoch: 19/30, Iter: 47/47, Loss: 0.1971
# Train Fine-Tuning, Epoch: 20/30, Iter: 47/47, Loss: 0.2423
# Train Fine-Tuning, Epoch: 21/30, Iter: 47/47, Loss: 0.1671
# Train Fine-Tuning, Epoch: 22/30, Iter: 47/47, Loss: 0.2352
# Train Fine-Tuning, Epoch: 23/30, Iter: 47/47, Loss: 0.1971
# Train Fine-Tuning, Epoch: 24/30, Iter: 47/47, Loss: 0.1797
# Train Fine-Tuning, Epoch: 25/30, Iter: 47/47, Loss: 0.1516
# Train Fine-Tuning, Epoch: 26/30, Iter: 47/47, Loss: 0.2116
# Train Fine-Tuning, Epoch: 27/30, Iter: 47/47, Loss: 0.1369
# Train Fine-Tuning, Epoch: 28/30, Iter: 47/47, Loss: 0.1717
# Train Fine-Tuning, Epoch: 29/30, Iter: 47/47, Loss: 0.1668
# Train Fine-Tuning, Epoch: 30/30, Iter: 47/47, Loss: 0.1491
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.928000

# %%
# Get the dataloaders of the training dataset
train_loader, test_loader = get_mnist_loader(batch_size=batch_size)

input_dim = 784
# Define the autoencoder layers
# Try different values for the dimensions of the hidden layers and the number of layers
encoder_1 = AutoEncoderLayer(input_dim = input_dim, hidden_dim = 512, SelfTraining=True)
encoder_2 = AutoEncoderLayer(input_dim = 512, hidden_dim = 256, SelfTraining=True)
encoder_3 = AutoEncoderLayer(input_dim = 256, hidden_dim = 64, SelfTraining=True)

encoders_list = [encoder_1, encoder_2, encoder_3]
num_layers = len(encoders_list)


# Pre-train each layer
for level in range(num_layers):
   train_layer(layers_list=encoders_list, train_loader=train_loader, test_loader=test_loader, layer=level, epochs=num_layer_wise_epochs, validate=True)

# Build the stacked autoencoder
SAE_model = StackedAutoEncoderClassifier(autoencoder_list=encoders_list, num_classes = 10)
# Print the model
print(SAE_model)

# First train the classification layer
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_classifier_epochs, fine_tuning = False)

# Train the whole model and perform fine-tuning
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_finetuning_epochs, fine_tuning = True)


# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
import os
if not os.path.exists('./models'):
   os.makedirs('./models')
torch.save(SAE_model, './models/sae_model2.pt')
# Out:
# Train Layer: 0, Epoch: 1/20, Iter: 47/47, Loss: 0.2079
# Train Layer: 0, Epoch: 2/20, Iter: 47/47, Loss: 0.1837
# Train Layer: 0, Epoch: 3/20, Iter: 47/47, Loss: 0.1647
# Train Layer: 0, Epoch: 4/20, Iter: 47/47, Loss: 0.1491
# Train Layer: 0, Epoch: 5/20, Iter: 47/47, Loss: 0.1370
# Train Layer: 0, Epoch: 6/20, Iter: 47/47, Loss: 0.1256
# Train Layer: 0, Epoch: 7/20, Iter: 47/47, Loss: 0.1173
# Train Layer: 0, Epoch: 8/20, Iter: 47/47, Loss: 0.1108
# Train Layer: 0, Epoch: 9/20, Iter: 47/47, Loss: 0.1050
# Train Layer: 0, Epoch: 10/20, Iter: 47/47, Loss: 0.1013
# Train Layer: 0, Epoch: 11/20, Iter: 47/47, Loss: 0.0958
# Train Layer: 0, Epoch: 12/20, Iter: 47/47, Loss: 0.0952
# Train Layer: 0, Epoch: 13/20, Iter: 47/47, Loss: 0.0930
# Train Layer: 0, Epoch: 14/20, Iter: 47/47, Loss: 0.0877
# Train Layer: 0, Epoch: 15/20, Iter: 47/47, Loss: 0.0871
# Train Layer: 0, Epoch: 16/20, Iter: 47/47, Loss: 0.0865
# Train Layer: 0, Epoch: 17/20, Iter: 47/47, Loss: 0.0838
# Train Layer: 0, Epoch: 18/20, Iter: 47/47, Loss: 0.0844
# Train Layer: 0, Epoch: 19/20, Iter: 47/47, Loss: 0.0800
# Train Layer: 0, Epoch: 20/20, Iter: 47/47, Loss: 0.0799
# Train Layer: 1, Epoch: 1/20, Iter: 47/47, Loss: 0.0083
# Train Layer: 1, Epoch: 2/20, Iter: 47/47, Loss: 0.0072
# Train Layer: 1, Epoch: 3/20, Iter: 47/47, Loss: 0.0062
# Train Layer: 1, Epoch: 4/20, Iter: 47/47, Loss: 0.0056
# Train Layer: 1, Epoch: 5/20, Iter: 47/47, Loss: 0.0050
# Train Layer: 1, Epoch: 6/20, Iter: 47/47, Loss: 0.0043
# Train Layer: 1, Epoch: 7/20, Iter: 47/47, Loss: 0.0043
# Train Layer: 1, Epoch: 8/20, Iter: 47/47, Loss: 0.0039
# Train Layer: 1, Epoch: 9/20, Iter: 47/47, Loss: 0.0035
# Train Layer: 1, Epoch: 10/20, Iter: 47/47, Loss: 0.0032
# Train Layer: 1, Epoch: 11/20, Iter: 47/47, Loss: 0.0030
# Train Layer: 1, Epoch: 12/20, Iter: 47/47, Loss: 0.0029
# Train Layer: 1, Epoch: 13/20, Iter: 47/47, Loss: 0.0026
# Train Layer: 1, Epoch: 14/20, Iter: 47/47, Loss: 0.0026
# Train Layer: 1, Epoch: 15/20, Iter: 47/47, Loss: 0.0024
# Train Layer: 1, Epoch: 16/20, Iter: 47/47, Loss: 0.0022
# Train Layer: 1, Epoch: 17/20, Iter: 47/47, Loss: 0.0021
# Train Layer: 1, Epoch: 18/20, Iter: 47/47, Loss: 0.0021
# Train Layer: 1, Epoch: 19/20, Iter: 47/47, Loss: 0.0019
# Train Layer: 1, Epoch: 20/20, Iter: 47/47, Loss: 0.0019
# Train Layer: 2, Epoch: 1/20, Iter: 47/47, Loss: 0.0105
# Train Layer: 2, Epoch: 2/20, Iter: 47/47, Loss: 0.0097
# Train Layer: 2, Epoch: 3/20, Iter: 47/47, Loss: 0.0089
# Train Layer: 2, Epoch: 4/20, Iter: 47/47, Loss: 0.0083
# Train Layer: 2, Epoch: 5/20, Iter: 47/47, Loss: 0.0076
# Train Layer: 2, Epoch: 6/20, Iter: 47/47, Loss: 0.0070
# Train Layer: 2, Epoch: 7/20, Iter: 47/47, Loss: 0.0065
# Train Layer: 2, Epoch: 8/20, Iter: 47/47, Loss: 0.0060
# Train Layer: 2, Epoch: 9/20, Iter: 47/47, Loss: 0.0056
# Train Layer: 2, Epoch: 10/20, Iter: 47/47, Loss: 0.0052
# Train Layer: 2, Epoch: 11/20, Iter: 47/47, Loss: 0.0048
# Train Layer: 2, Epoch: 12/20, Iter: 47/47, Loss: 0.0045
# Train Layer: 2, Epoch: 13/20, Iter: 47/47, Loss: 0.0041
# Train Layer: 2, Epoch: 14/20, Iter: 47/47, Loss: 0.0038
# Train Layer: 2, Epoch: 15/20, Iter: 47/47, Loss: 0.0035
# Train Layer: 2, Epoch: 16/20, Iter: 47/47, Loss: 0.0033
# Train Layer: 2, Epoch: 17/20, Iter: 47/47, Loss: 0.0031
# Train Layer: 2, Epoch: 18/20, Iter: 47/47, Loss: 0.0028
# Train Layer: 2, Epoch: 19/20, Iter: 47/47, Loss: 0.0026
# Train Layer: 2, Epoch: 20/20, Iter: 47/47, Loss: 0.0024
# StackedAutoEncoderClassifier(
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=512, bias=True)
#       (1): Sigmoid()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): Sigmoid()
#     )
#     (2): Sequential(
#       (0): Linear(in_features=256, out_features=64, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (classification_layer): Linear(in_features=64, out_features=10, bias=True)
# )
# >> start training whole model
# Train Classifier, Epoch: 1/10, Iter: 47/47, Loss: 2.3217
# Train Classifier, Epoch: 2/10, Iter: 47/47, Loss: 2.3110
# Train Classifier, Epoch: 3/10, Iter: 47/47, Loss: 2.3085
# Train Classifier, Epoch: 4/10, Iter: 47/47, Loss: 2.2995
# Train Classifier, Epoch: 5/10, Iter: 47/47, Loss: 2.3252
# Train Classifier, Epoch: 6/10, Iter: 47/47, Loss: 2.3145
# Train Classifier, Epoch: 7/10, Iter: 47/47, Loss: 2.3171
# Train Classifier, Epoch: 8/10, Iter: 47/47, Loss: 2.2958
# Train Classifier, Epoch: 9/10, Iter: 47/47, Loss: 2.3054
# Train Classifier, Epoch: 10/10, Iter: 47/47, Loss: 2.2926
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.097000
# >> start training whole model
# Train Fine-Tuning, Epoch: 1/30, Iter: 47/47, Loss: 2.2990
# Train Fine-Tuning, Epoch: 2/30, Iter: 47/47, Loss: 2.3043
# Train Fine-Tuning, Epoch: 3/30, Iter: 47/47, Loss: 2.2985
# Train Fine-Tuning, Epoch: 4/30, Iter: 47/47, Loss: 2.3032
# Train Fine-Tuning, Epoch: 5/30, Iter: 47/47, Loss: 2.3136
# Train Fine-Tuning, Epoch: 6/30, Iter: 47/47, Loss: 2.2880
# Train Fine-Tuning, Epoch: 7/30, Iter: 47/47, Loss: 2.3099
# Train Fine-Tuning, Epoch: 8/30, Iter: 47/47, Loss: 2.3033
# Train Fine-Tuning, Epoch: 9/30, Iter: 47/47, Loss: 2.3072
# Train Fine-Tuning, Epoch: 10/30, Iter: 47/47, Loss: 2.3140
# Train Fine-Tuning, Epoch: 11/30, Iter: 47/47, Loss: 2.2939
# Train Fine-Tuning, Epoch: 12/30, Iter: 47/47, Loss: 2.3045
# Train Fine-Tuning, Epoch: 13/30, Iter: 47/47, Loss: 2.3184
# Train Fine-Tuning, Epoch: 14/30, Iter: 47/47, Loss: 2.3006
# Train Fine-Tuning, Epoch: 15/30, Iter: 47/47, Loss: 2.3100
# Train Fine-Tuning, Epoch: 16/30, Iter: 47/47, Loss: 2.3104
# Train Fine-Tuning, Epoch: 17/30, Iter: 47/47, Loss: 2.3083
# Train Fine-Tuning, Epoch: 18/30, Iter: 47/47, Loss: 2.2947
# Train Fine-Tuning, Epoch: 19/30, Iter: 47/47, Loss: 2.2914
# Train Fine-Tuning, Epoch: 20/30, Iter: 47/47, Loss: 2.2911
# Train Fine-Tuning, Epoch: 21/30, Iter: 47/47, Loss: 2.1521
# Train Fine-Tuning, Epoch: 22/30, Iter: 47/47, Loss: 1.9408
# Train Fine-Tuning, Epoch: 23/30, Iter: 47/47, Loss: 1.8291
# Train Fine-Tuning, Epoch: 24/30, Iter: 47/47, Loss: 1.7700
# Train Fine-Tuning, Epoch: 25/30, Iter: 47/47, Loss: 1.3942
# Train Fine-Tuning, Epoch: 26/30, Iter: 47/47, Loss: 1.2745
# Train Fine-Tuning, Epoch: 27/30, Iter: 47/47, Loss: 1.1682
# Train Fine-Tuning, Epoch: 28/30, Iter: 47/47, Loss: 1.1126
# Train Fine-Tuning, Epoch: 29/30, Iter: 47/47, Loss: 0.8641
# Train Fine-Tuning, Epoch: 30/30, Iter: 47/47, Loss: 1.0173
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.650000

# %%
# Get the dataloaders of the training dataset
train_loader, test_loader = get_mnist_loader(batch_size=batch_size)

input_dim = 784
# Define the autoencoder layers
# Try different values for the dimensions of the hidden layers and the number of layers
encoder_1 = AutoEncoderLayer(input_dim = input_dim, hidden_dim = 512, SelfTraining=True)

encoders_list = [encoder_1]
num_layers = len(encoders_list)


# Pre-train each layer
for level in range(num_layers):
   train_layer(layers_list=encoders_list, train_loader=train_loader, test_loader=test_loader, layer=level, epochs=num_layer_wise_epochs, validate=True)

# Build the stacked autoencoder
SAE_model = StackedAutoEncoderClassifier(autoencoder_list=encoders_list, num_classes = 10)
# Print the model
print(SAE_model)

# First train the classification layer
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_classifier_epochs, fine_tuning = False)

# Train the whole model and perform fine-tuning
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_finetuning_epochs, fine_tuning = True)


# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
import os
if not os.path.exists('./models'):
   os.makedirs('./models')
torch.save(SAE_model, './models/sae_model2.pt')
# Out:
# Train Layer: 0, Epoch: 1/20, Iter: 47/47, Loss: 0.2078
# Train Layer: 0, Epoch: 2/20, Iter: 47/47, Loss: 0.1833
# Train Layer: 0, Epoch: 3/20, Iter: 47/47, Loss: 0.1646
# Train Layer: 0, Epoch: 4/20, Iter: 47/47, Loss: 0.1482
# Train Layer: 0, Epoch: 5/20, Iter: 47/47, Loss: 0.1357
# Train Layer: 0, Epoch: 6/20, Iter: 47/47, Loss: 0.1259
# Train Layer: 0, Epoch: 7/20, Iter: 47/47, Loss: 0.1183
# Train Layer: 0, Epoch: 8/20, Iter: 47/47, Loss: 0.1117
# Train Layer: 0, Epoch: 9/20, Iter: 47/47, Loss: 0.1056
# Train Layer: 0, Epoch: 10/20, Iter: 47/47, Loss: 0.1004
# Train Layer: 0, Epoch: 11/20, Iter: 47/47, Loss: 0.0972
# Train Layer: 0, Epoch: 12/20, Iter: 47/47, Loss: 0.0939
# Train Layer: 0, Epoch: 13/20, Iter: 47/47, Loss: 0.0895
# Train Layer: 0, Epoch: 14/20, Iter: 47/47, Loss: 0.0885
# Train Layer: 0, Epoch: 15/20, Iter: 47/47, Loss: 0.0859
# Train Layer: 0, Epoch: 16/20, Iter: 47/47, Loss: 0.0857
# Train Layer: 0, Epoch: 17/20, Iter: 47/47, Loss: 0.0840
# Train Layer: 0, Epoch: 18/20, Iter: 47/47, Loss: 0.0826
# Train Layer: 0, Epoch: 19/20, Iter: 47/47, Loss: 0.0818
# Train Layer: 0, Epoch: 20/20, Iter: 47/47, Loss: 0.0784
# StackedAutoEncoderClassifier(
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=512, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (classification_layer): Linear(in_features=512, out_features=10, bias=True)
# )
# >> start training whole model
# Train Classifier, Epoch: 1/10, Iter: 47/47, Loss: 2.2814
# Train Classifier, Epoch: 2/10, Iter: 47/47, Loss: 1.6050
# Train Classifier, Epoch: 3/10, Iter: 47/47, Loss: 0.8746
# Train Classifier, Epoch: 4/10, Iter: 47/47, Loss: 0.4169
# Train Classifier, Epoch: 5/10, Iter: 47/47, Loss: 0.4264
# Train Classifier, Epoch: 6/10, Iter: 47/47, Loss: 0.5049
# Train Classifier, Epoch: 7/10, Iter: 47/47, Loss: 0.3876
# Train Classifier, Epoch: 8/10, Iter: 47/47, Loss: 0.3202
# Train Classifier, Epoch: 9/10, Iter: 47/47, Loss: 0.2258
# Train Classifier, Epoch: 10/10, Iter: 47/47, Loss: 0.2635
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.908000
# >> start training whole model
# Train Fine-Tuning, Epoch: 1/30, Iter: 47/47, Loss: 0.1953
# Train Fine-Tuning, Epoch: 2/30, Iter: 47/47, Loss: 0.1850
# Train Fine-Tuning, Epoch: 3/30, Iter: 47/47, Loss: 0.1654
# Train Fine-Tuning, Epoch: 4/30, Iter: 47/47, Loss: 0.1999
# Train Fine-Tuning, Epoch: 5/30, Iter: 47/47, Loss: 0.1466
# Train Fine-Tuning, Epoch: 6/30, Iter: 47/47, Loss: 0.1180
# Train Fine-Tuning, Epoch: 7/30, Iter: 47/47, Loss: 0.2548
# Train Fine-Tuning, Epoch: 8/30, Iter: 47/47, Loss: 0.1046
# Train Fine-Tuning, Epoch: 9/30, Iter: 47/47, Loss: 0.2044
# Train Fine-Tuning, Epoch: 10/30, Iter: 47/47, Loss: 0.0946
# Train Fine-Tuning, Epoch: 11/30, Iter: 47/47, Loss: 0.0871
# Train Fine-Tuning, Epoch: 12/30, Iter: 47/47, Loss: 0.1239
# Train Fine-Tuning, Epoch: 13/30, Iter: 47/47, Loss: 0.1202
# Train Fine-Tuning, Epoch: 14/30, Iter: 47/47, Loss: 0.2169
# Train Fine-Tuning, Epoch: 15/30, Iter: 47/47, Loss: 0.0850
# Train Fine-Tuning, Epoch: 16/30, Iter: 47/47, Loss: 0.1370
# Train Fine-Tuning, Epoch: 17/30, Iter: 47/47, Loss: 0.0807
# Train Fine-Tuning, Epoch: 18/30, Iter: 47/47, Loss: 0.0702
# Train Fine-Tuning, Epoch: 19/30, Iter: 47/47, Loss: 0.1220
# Train Fine-Tuning, Epoch: 20/30, Iter: 47/47, Loss: 0.1147
# Train Fine-Tuning, Epoch: 21/30, Iter: 47/47, Loss: 0.0371
# Train Fine-Tuning, Epoch: 22/30, Iter: 47/47, Loss: 0.1003
# Train Fine-Tuning, Epoch: 23/30, Iter: 47/47, Loss: 0.0709
# Train Fine-Tuning, Epoch: 24/30, Iter: 47/47, Loss: 0.0406
# Train Fine-Tuning, Epoch: 25/30, Iter: 47/47, Loss: 0.0481
# Train Fine-Tuning, Epoch: 26/30, Iter: 47/47, Loss: 0.0718
# Train Fine-Tuning, Epoch: 27/30, Iter: 47/47, Loss: 0.0421
# Train Fine-Tuning, Epoch: 28/30, Iter: 47/47, Loss: 0.0549
# Train Fine-Tuning, Epoch: 29/30, Iter: 47/47, Loss: 0.0441
# Train Fine-Tuning, Epoch: 30/30, Iter: 47/47, Loss: 0.0548
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.929000

# %%
# Get the dataloaders of the training dataset
train_loader, test_loader = get_mnist_loader(batch_size=batch_size)

input_dim = 784
# Define the autoencoder layers
# Try different values for the dimensions of the hidden layers and the number of layers
encoder_1 = AutoEncoderLayer(input_dim = input_dim, hidden_dim = 256, SelfTraining=True)
encoder_2 = AutoEncoderLayer(input_dim = 256, hidden_dim = 10, SelfTraining=True)

encoders_list = [encoder_1, encoder_2]
num_layers = len(encoders_list)


# Pre-train each layer
for level in range(num_layers):
   train_layer(layers_list=encoders_list, train_loader=train_loader, test_loader=test_loader, layer=level, epochs=num_layer_wise_epochs, validate=True)

# Build the stacked autoencoder
SAE_model = StackedAutoEncoderClassifier(autoencoder_list=encoders_list, num_classes = 10)
# Print the model
print(SAE_model)

# First train the classification layer
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_classifier_epochs, fine_tuning = False)

# Train the whole model and perform fine-tuning
train_classifier(model=SAE_model, train_loader=train_loader, test_loader=test_loader, epochs=num_finetuning_epochs, fine_tuning = True)


# Save the model (refer: https://pytorch.org/docs/master/notes/serialization.html)
import os
if not os.path.exists('./models'):
   os.makedirs('./models')
torch.save(SAE_model, './models/sae_model2.pt')
# Out:
# Train Layer: 0, Epoch: 1/20, Iter: 47/47, Loss: 0.2168
# Train Layer: 0, Epoch: 2/20, Iter: 47/47, Loss: 0.2039
# Train Layer: 0, Epoch: 3/20, Iter: 47/47, Loss: 0.1911
# Train Layer: 0, Epoch: 4/20, Iter: 47/47, Loss: 0.1802
# Train Layer: 0, Epoch: 5/20, Iter: 47/47, Loss: 0.1703
# Train Layer: 0, Epoch: 6/20, Iter: 47/47, Loss: 0.1599
# Train Layer: 0, Epoch: 7/20, Iter: 47/47, Loss: 0.1515
# Train Layer: 0, Epoch: 8/20, Iter: 47/47, Loss: 0.1433
# Train Layer: 0, Epoch: 9/20, Iter: 47/47, Loss: 0.1362
# Train Layer: 0, Epoch: 10/20, Iter: 47/47, Loss: 0.1309
# Train Layer: 0, Epoch: 11/20, Iter: 47/47, Loss: 0.1252
# Train Layer: 0, Epoch: 12/20, Iter: 47/47, Loss: 0.1200
# Train Layer: 0, Epoch: 13/20, Iter: 47/47, Loss: 0.1160
# Train Layer: 0, Epoch: 14/20, Iter: 47/47, Loss: 0.1113
# Train Layer: 0, Epoch: 15/20, Iter: 47/47, Loss: 0.1072
# Train Layer: 0, Epoch: 16/20, Iter: 47/47, Loss: 0.1048
# Train Layer: 0, Epoch: 17/20, Iter: 47/47, Loss: 0.1017
# Train Layer: 0, Epoch: 18/20, Iter: 47/47, Loss: 0.0978
# Train Layer: 0, Epoch: 19/20, Iter: 47/47, Loss: 0.0977
# Train Layer: 0, Epoch: 20/20, Iter: 47/47, Loss: 0.0937
# Train Layer: 1, Epoch: 1/20, Iter: 47/47, Loss: 0.0159
# Train Layer: 1, Epoch: 2/20, Iter: 47/47, Loss: 0.0145
# Train Layer: 1, Epoch: 3/20, Iter: 47/47, Loss: 0.0141
# Train Layer: 1, Epoch: 4/20, Iter: 47/47, Loss: 0.0130
# Train Layer: 1, Epoch: 5/20, Iter: 47/47, Loss: 0.0132
# Train Layer: 1, Epoch: 6/20, Iter: 47/47, Loss: 0.0129
# Train Layer: 1, Epoch: 7/20, Iter: 47/47, Loss: 0.0131
# Train Layer: 1, Epoch: 8/20, Iter: 47/47, Loss: 0.0120
# Train Layer: 1, Epoch: 9/20, Iter: 47/47, Loss: 0.0119
# Train Layer: 1, Epoch: 10/20, Iter: 47/47, Loss: 0.0120
# Train Layer: 1, Epoch: 11/20, Iter: 47/47, Loss: 0.0117
# Train Layer: 1, Epoch: 12/20, Iter: 47/47, Loss: 0.0120
# Train Layer: 1, Epoch: 13/20, Iter: 47/47, Loss: 0.0115
# Train Layer: 1, Epoch: 14/20, Iter: 47/47, Loss: 0.0107
# Train Layer: 1, Epoch: 15/20, Iter: 47/47, Loss: 0.0109
# Train Layer: 1, Epoch: 16/20, Iter: 47/47, Loss: 0.0116
# Train Layer: 1, Epoch: 17/20, Iter: 47/47, Loss: 0.0111
# Train Layer: 1, Epoch: 18/20, Iter: 47/47, Loss: 0.0113
# Train Layer: 1, Epoch: 19/20, Iter: 47/47, Loss: 0.0108
# Train Layer: 1, Epoch: 20/20, Iter: 47/47, Loss: 0.0112
# StackedAutoEncoderClassifier(
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Sigmoid()
#     )
#     (1): Sequential(
#       (0): Linear(in_features=256, out_features=10, bias=True)
#       (1): Sigmoid()
#     )
#   )
#   (classification_layer): Linear(in_features=10, out_features=10, bias=True)
# )
# >> start training whole model
# Train Classifier, Epoch: 1/10, Iter: 47/47, Loss: 2.2952
# Train Classifier, Epoch: 2/10, Iter: 47/47, Loss: 2.2911
# Train Classifier, Epoch: 3/10, Iter: 47/47, Loss: 2.3049
# Train Classifier, Epoch: 4/10, Iter: 47/47, Loss: 2.2748
# Train Classifier, Epoch: 5/10, Iter: 47/47, Loss: 2.2912
# Train Classifier, Epoch: 6/10, Iter: 47/47, Loss: 2.3022
# Train Classifier, Epoch: 7/10, Iter: 47/47, Loss: 2.2744
# Train Classifier, Epoch: 8/10, Iter: 47/47, Loss: 2.1498
# Train Classifier, Epoch: 9/10, Iter: 47/47, Loss: 2.3817
# Train Classifier, Epoch: 10/10, Iter: 47/47, Loss: 2.4928
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.190000
# >> start training whole model
# Train Fine-Tuning, Epoch: 1/30, Iter: 47/47, Loss: 1.3053
# Train Fine-Tuning, Epoch: 2/30, Iter: 47/47, Loss: 1.0921
# Train Fine-Tuning, Epoch: 3/30, Iter: 47/47, Loss: 0.6829
# Train Fine-Tuning, Epoch: 4/30, Iter: 47/47, Loss: 0.9258
# Train Fine-Tuning, Epoch: 5/30, Iter: 47/47, Loss: 0.5407
# Train Fine-Tuning, Epoch: 6/30, Iter: 47/47, Loss: 0.6039
# Train Fine-Tuning, Epoch: 7/30, Iter: 47/47, Loss: 0.5412
# Train Fine-Tuning, Epoch: 8/30, Iter: 47/47, Loss: 0.5601
# Train Fine-Tuning, Epoch: 9/30, Iter: 47/47, Loss: 0.3505
# Train Fine-Tuning, Epoch: 10/30, Iter: 47/47, Loss: 0.3189
# Train Fine-Tuning, Epoch: 11/30, Iter: 47/47, Loss: 0.4454
# Train Fine-Tuning, Epoch: 12/30, Iter: 47/47, Loss: 0.3312
# Train Fine-Tuning, Epoch: 13/30, Iter: 47/47, Loss: 0.3795
# Train Fine-Tuning, Epoch: 14/30, Iter: 47/47, Loss: 0.2924
# Train Fine-Tuning, Epoch: 15/30, Iter: 47/47, Loss: 0.2334
# Train Fine-Tuning, Epoch: 16/30, Iter: 47/47, Loss: 0.3783
# Train Fine-Tuning, Epoch: 17/30, Iter: 47/47, Loss: 0.2448
# Train Fine-Tuning, Epoch: 18/30, Iter: 47/47, Loss: 0.1995
# Train Fine-Tuning, Epoch: 19/30, Iter: 47/47, Loss: 0.2370
# Train Fine-Tuning, Epoch: 20/30, Iter: 47/47, Loss: 0.2924
# Train Fine-Tuning, Epoch: 21/30, Iter: 47/47, Loss: 0.2046
# Train Fine-Tuning, Epoch: 22/30, Iter: 47/47, Loss: 0.2344
# Train Fine-Tuning, Epoch: 23/30, Iter: 47/47, Loss: 0.1857
# Train Fine-Tuning, Epoch: 24/30, Iter: 47/47, Loss: 0.2228
# Train Fine-Tuning, Epoch: 25/30, Iter: 47/47, Loss: 0.1322
# Train Fine-Tuning, Epoch: 26/30, Iter: 47/47, Loss: 0.1238
# Train Fine-Tuning, Epoch: 27/30, Iter: 47/47, Loss: 0.1077
# Train Fine-Tuning, Epoch: 28/30, Iter: 47/47, Loss: 0.1815
# Train Fine-Tuning, Epoch: 29/30, Iter: 47/47, Loss: 0.1160
# Train Fine-Tuning, Epoch: 30/30, Iter: 47/47, Loss: 0.0799
# << end training whole model
# Calculating accuracy on the whole test set
# Accuracy on the test set: 0.932000
